# %%
df=spark.read.csv("/FileStore/tables/50_Startups.csv",header=True,inferSchema=True)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df=df.toPandas()
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>R&amp;D Spend</th>
#       <th>Administration</th>
#       <th>Marketing Spend</th>
#       <th>State</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>165349.20</td>
#       <td>136897.80</td>
#       <td>471784.10</td>
#       <td>New York</td>
#       <td>192261.83</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>162597.70</td>
#       <td>151377.59</td>
#       <td>443898.53</td>
#       <td>California</td>
#       <td>191792.06</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>153441.51</td>
#       <td>101145.55</td>
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.isnull().sum()
# Out:
# Out[4]: R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %% [markdown]
# #####Encoding Categorical Column

# %%
import pandas as pd

df=pd.get_dummies(data=df,columns=["State"],drop_first=True)
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>R&amp;D Spend</th>
#       <th>Administration</th>
#       <th>Marketing Spend</th>
#       <th>Profit</th>
#       <th>State_Florida</th>
#       <th>State_New York</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>165349.20</td>
#       <td>136897.80</td>
#       <td>471784.10</td>
#       <td>192261.83</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>162597.70</td>
#       <td>151377.59</td>
#       <td>443898.53</td>
#       <td>191792.06</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %% [markdown]
# #####Handling Outliers

# %%
def Handling_Outliers(dataset):
  for col in dataset:
    q1=dataset[col].astype('float').quantile(0.25)
    q3=dataset[col].astype('float').quantile(0.75)

    iqr=q3-q1

    lower_percentile=q1-1.5*iqr
    upper_percentile=q3+1.5*iqr

    dataset=dataset[dataset[col].astype('float')>=lower_percentile]
    dataset=dataset[dataset[col].astype('float')<=upper_percentile]

    return dataset

# %%
df2=Handling_Outliers(df)
df2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>R&amp;D Spend</th>
#       <th>Administration</th>
#       <th>Marketing Spend</th>
#       <th>Profit</th>
#       <th>State_Florida</th>
#       <th>State_New York</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>165349.20</td>
#       <td>136897.80</td>
#       <td>471784.10</td>
#       <td>192261.83</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>162597.70</td>
#       <td>151377.59</td>
#       <td>443898.53</td>
#       <td>191792.06</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
y=df2.pop("Profit")
X=df2

# %%
y
# Out:
# Out[9]: 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
X
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>R&amp;D Spend</th>
#       <th>Administration</th>
#       <th>Marketing Spend</th>
#       <th>State_Florida</th>
#       <th>State_New York</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>165349.20</td>
#       <td>136897.80</td>
#       <td>471784.10</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>162597.70</td>
#       <td>151377.59</td>
#       <td>443898.53</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>153441.51</td>
#       <td>101145.55</td>
#       <td>407934.54</td>
# ...

# %% [markdown]
# #####Train Test Split

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=100)

# %%
X_train
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>R&amp;D Spend</th>
#       <th>Administration</th>
#       <th>Marketing Spend</th>
#       <th>State_Florida</th>
#       <th>State_New York</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>165349.20</td>
#       <td>136897.80</td>
#       <td>471784.10</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>100671.96</td>
#       <td>91790.61</td>
#       <td>249744.55</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>91749.16</td>
#       <td>114175.79</td>
#       <td>294919.57</td>
# ...

# %%
X_test
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>R&amp;D Spend</th>
#       <th>Administration</th>
#       <th>Marketing Spend</th>
#       <th>State_Florida</th>
#       <th>State_New York</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6</th>
#       <td>134615.46</td>
#       <td>147198.87</td>
#       <td>127716.82</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>28663.76</td>
#       <td>127056.21</td>
#       <td>201126.82</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>44069.95</td>
#       <td>51283.14</td>
#       <td>197029.42</td>
# ...

# %%
y_train
# Out:
# Out[14]: 0     192261.83
# 11    144259.40
# 18    124266.90
# 45     64926.08
# 38     81229.06
# 25    107404.34
# 26    105733.54
# 35     96479.51
# 17    125370.37
# 7     155752.60
# 47     42559.73
# 31     97483.56
# 32     97427.84
# 19    122776.86
# 21    111313.02
# 13    134307.35
# 1     191792.06
# 4     166187.94
# 12    141585.52
# 27    105008.31
# 40     78239.91
# 22    110352.25
# 29    101004.64
# 9     149759.96
# 16    126992.93
# 44     65200.33
# 48     35673.41
# 46     49490.75
# 14    132602.65
# 41     77798.83
# 2     191050.39
# 34     96712.80
# 30     99937.59
# 10    146121.95
# 15    129917.04
# 23    108733.99
# 39     81005.76
# 3     182901.99
# 24    108552.04
# 8     152211.77
# Name: Profit, dtype: float64

# %%
y_test
# Out:
# Out[15]: 6     156122.51
# 36     90708.19
# 37     89949.14
# 28    103282.38
# 43     69758.98
# 49     14681.40
# 5     156991.12
# 33     96778.92
# 20    118474.03
# 42     71498.49
# Name: Profit, dtype: float64

# %% [markdown]
# #####Model Creating

# %%
from sklearn.linear_model import LinearRegression

model2=LinearRegression()

# %%
model2.fit(X_train,y_train)
# Out:
# Out[17]: LinearRegression()

# %%
y_pred=model2.predict(X_test)

# %%
y_test
# Out:
# Out[19]: 6     156122.51
# 36     90708.19
# 37     89949.14
# 28    103282.38
# 43     69758.98
# 49     14681.40
# 5     156991.12
# 33     96778.92
# 20    118474.03
# 42     71498.49
# Name: Profit, dtype: float64

# %%
y_pred
# Out:
# Out[20]: array([161280.45087761,  73626.4714843 ,  94136.64612149,  99269.70400154,
#         59926.24314732,  51133.94307934, 163746.27541068,  97185.11390795,
#        119187.6783585 ,  73867.24728982])

# %%
# import matplotlib.pyplot as plt

# plt.style.use('default')
# plt.style.use('ggplot')

# fig, ax = plt.subplots(figsize=(7, 3.5))

# ax.plot(X_test, y_pred, color='k', label='Regression model')
# ax.scatter(X, y, edgecolor='k', facecolor='grey', alpha=0.7, label='Sample data')
# ax.set_ylabel('Gas production (Mcf/day)', fontsize=14)
# ax.set_xlabel('Porosity (%)', fontsize=14)
# ax.legend(facecolor='white', fontsize=11)
# ax.text(0.55, 0.15, '$y = %.2f x_1 - %.2f $' % (model.coef_[0], abs(model.intercept_)), fontsize=17, transform=ax.transAxes)

# fig.tight_layout()

# %% [markdown]
# OLS

# %%
import statsmodels.api as sm
X=sm.add_constant(X)

# %%
X
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>const</th>
#       <th>R&amp;D Spend</th>
#       <th>Administration</th>
#       <th>Marketing Spend</th>
#       <th>State_Florida</th>
#       <th>State_New York</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>165349.20</td>
#       <td>136897.80</td>
#       <td>471784.10</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>162597.70</td>
#       <td>151377.59</td>
#       <td>443898.53</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
model=sm.OLS(y,X)
model=model.fit()

# %%
model.summary2()
# Out:
# <table class="simpletable">
# <tr>
#         <td>Model:</td>               <td>OLS</td>         <td>Adj. R-squared:</td>      <td>0.945</td>
# </tr>
# <tr>
#   <td>Dependent Variable:</td>      <td>Profit</td>             <td>AIC:</td>          <td>1062.7649</td>
# </tr>
# <tr>
#          <td>Date:</td>        <td>2024-09-06 15:11</td>        <td>BIC:</td>          <td>1074.2370</td>
# </tr>
# <tr>
#    <td>No. Observations:</td>         <td>50</td>          <td>Log-Likelihood:</td>     <td>-525.38</td>
# </tr>
# <tr>
#        <td>Df Model:</td>              <td>5</td>           <td>F-statistic:</td>        <td>169.9</td>
# </tr>
# <tr>
#      <td>Df Residuals:</td>           <td>44</td>        <td>Prob (F-statistic):</td>  <td>1.34e-27</td>
# </tr>
# <tr>
#       <td>R-squared:</td>            <td>0.951</td>            <td>Scale:</td>        <td>8.9099e+07</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
# ...

# %%
X=X.iloc[:,0:5]

# %%
X
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>const</th>
#       <th>R&amp;D Spend</th>
#       <th>Administration</th>
#       <th>Marketing Spend</th>
#       <th>State_Florida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>165349.20</td>
#       <td>136897.80</td>
#       <td>471784.10</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>162597.70</td>
#       <td>151377.59</td>
#       <td>443898.53</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>153441.51</td>
#       <td>101145.55</td>
# ...

# %%
model=sm.OLS(y,X)
model=model.fit()

# %%
model.summary2()
# Out:
# <table class="simpletable">
# <tr>
#         <td>Model:</td>               <td>OLS</td>         <td>Adj. R-squared:</td>      <td>0.946</td>
# </tr>
# <tr>
#   <td>Dependent Variable:</td>      <td>Profit</td>             <td>AIC:</td>          <td>1060.7651</td>
# </tr>
# <tr>
#          <td>Date:</td>        <td>2024-09-06 15:15</td>        <td>BIC:</td>          <td>1070.3252</td>
# </tr>
# <tr>
#    <td>No. Observations:</td>         <td>50</td>          <td>Log-Likelihood:</td>     <td>-525.38</td>
# </tr>
# <tr>
#        <td>Df Model:</td>              <td>4</td>           <td>F-statistic:</td>        <td>217.2</td>
# </tr>
# <tr>
#      <td>Df Residuals:</td>           <td>45</td>        <td>Prob (F-statistic):</td>  <td>8.49e-29</td>
# </tr>
# <tr>
#       <td>R-squared:</td>            <td>0.951</td>            <td>Scale:</td>        <td>8.7119e+07</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
# ...

# %%
X=X.iloc[:,0:4]
X
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>const</th>
#       <th>R&amp;D Spend</th>
#       <th>Administration</th>
#       <th>Marketing Spend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>165349.20</td>
#       <td>136897.80</td>
#       <td>471784.10</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>162597.70</td>
#       <td>151377.59</td>
#       <td>443898.53</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>153441.51</td>
#       <td>101145.55</td>
#       <td>407934.54</td>
#     </tr>
#     <tr>
#       <th>3</th>
# ...

# %%
model=sm.OLS(y,X)
model=model.fit()

# %%
model.summary2()
# Out:
# <table class="simpletable">
# <tr>
#         <td>Model:</td>               <td>OLS</td>         <td>Adj. R-squared:</td>      <td>0.948</td>
# </tr>
# <tr>
#   <td>Dependent Variable:</td>      <td>Profit</td>             <td>AIC:</td>          <td>1058.7715</td>
# </tr>
# <tr>
#          <td>Date:</td>        <td>2024-09-06 15:17</td>        <td>BIC:</td>          <td>1066.4196</td>
# </tr>
# <tr>
#    <td>No. Observations:</td>         <td>50</td>          <td>Log-Likelihood:</td>     <td>-525.39</td>
# </tr>
# <tr>
#        <td>Df Model:</td>              <td>3</td>           <td>F-statistic:</td>        <td>296.0</td>
# </tr>
# <tr>
#      <td>Df Residuals:</td>           <td>46</td>        <td>Prob (F-statistic):</td>  <td>4.53e-30</td>
# </tr>
# <tr>
#       <td>R-squared:</td>            <td>0.951</td>            <td>Scale:</td>        <td>8.5236e+07</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
# ...

# %%
X=X.iloc[:,[0,1,3]]
X
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>const</th>
#       <th>R&amp;D Spend</th>
#       <th>Marketing Spend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>165349.20</td>
#       <td>471784.10</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>162597.70</td>
#       <td>443898.53</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>153441.51</td>
#       <td>407934.54</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.0</td>
#       <td>144372.41</td>
#       <td>383199.62</td>
#     </tr>
#     <tr>
#       <th>4</th>
# ...

# %%
model=sm.OLS(y,X)
model=model.fit()

# %%
model.summary2()
# Out:
# <table class="simpletable">
# <tr>
#         <td>Model:</td>               <td>OLS</td>         <td>Adj. R-squared:</td>      <td>0.948</td>
# </tr>
# <tr>
#   <td>Dependent Variable:</td>      <td>Profit</td>             <td>AIC:</td>          <td>1057.0708</td>
# </tr>
# <tr>
#          <td>Date:</td>        <td>2024-09-06 15:32</td>        <td>BIC:</td>          <td>1062.8068</td>
# </tr>
# <tr>
#    <td>No. Observations:</td>         <td>50</td>          <td>Log-Likelihood:</td>     <td>-525.54</td>
# </tr>
# <tr>
#        <td>Df Model:</td>              <td>2</td>           <td>F-statistic:</td>        <td>450.8</td>
# </tr>
# <tr>
#      <td>Df Residuals:</td>           <td>47</td>        <td>Prob (F-statistic):</td>  <td>2.16e-31</td>
# </tr>
# <tr>
#       <td>R-squared:</td>            <td>0.950</td>            <td>Scale:</td>        <td>8.3923e+07</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
# ...

# %%
X=X.iloc[:,0:2]
X
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>const</th>
#       <th>R&amp;D Spend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>165349.20</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>162597.70</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>153441.51</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.0</td>
#       <td>144372.41</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.0</td>
#       <td>142107.34</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1.0</td>
#       <td>131876.90</td>
#     </tr>
# ...

# %%
model=sm.OLS(y,X)
model=model.fit()

# %%
model.summary2()
# Out:
# <table class="simpletable">
# <tr>
#         <td>Model:</td>               <td>OLS</td>         <td>Adj. R-squared:</td>      <td>0.945</td>
# </tr>
# <tr>
#   <td>Dependent Variable:</td>      <td>Profit</td>             <td>AIC:</td>          <td>1058.8730</td>
# </tr>
# <tr>
#          <td>Date:</td>        <td>2024-09-06 15:40</td>        <td>BIC:</td>          <td>1062.6971</td>
# </tr>
# <tr>
#    <td>No. Observations:</td>         <td>50</td>          <td>Log-Likelihood:</td>     <td>-527.44</td>
# </tr>
# <tr>
#        <td>Df Model:</td>              <td>1</td>           <td>F-statistic:</td>        <td>849.8</td>
# </tr>
# <tr>
#      <td>Df Residuals:</td>           <td>48</td>        <td>Prob (F-statistic):</td>  <td>3.50e-32</td>
# </tr>
# <tr>
#       <td>R-squared:</td>            <td>0.947</td>            <td>Scale:</td>        <td>8.8668e+07</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
# ...

# %%
print("Hello")
# Out:
# Hello
